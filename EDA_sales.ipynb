# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Import the data**

# %%
df_stores=pd.read_csv(r'E:\FinalProject\data\stores_data_set.csv')
df_stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
df_features=pd.read_csv(r'E:\FinalProject\data\Features_data_set.csv')
df_features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
df_sales=pd.read_csv(r'E:\FinalProject\data\sales_data_set.csv')
df_sales
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %% [markdown]
# # **Merge the data in a unique DataFrame**

# %%
df_stores_features=df_stores.merge(right=df_features,on='Store')

df_merge=df_stores_features.merge(right=df_sales,on=['Store', 'Date', 'IsHoliday'])
df_merge.sample(10)
# Out:
#         Store Type    Size        Date  Temperature  Fuel_Price  MarkDown1  \
# 34112       4    A  205863  22/04/2011        68.80       3.781        NaN
# 98649      11    A  207499  23/04/2010        68.37       2.795        NaN
# 254640     26    A  152513  30/03/2012        33.33       3.921    8827.14
# 119550     13    A  219622  06/08/2010        81.24       2.802        NaN
# 212913     22    B  119557  23/09/2011        62.36       3.758        NaN
# 260958     27    A  204184  18/03/2011        46.65       3.796        NaN
# 367191     39    A  184109  14/10/2011        73.79       3.274        NaN
# 204431     21    B  140167  20/01/2012        52.21       3.268    4436.00
# 44779       5    B   34875  12/08/2011        90.16       3.638        NaN
# 344805     36    A   39910  03/02/2012        61.33       3.421    1786.27
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# ...

# %% [markdown]
# # **Checking Data and feature**

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Type          421570 non-null  object
#  2   Size          421570 non-null  int64
#  3   Date          421570 non-null  object
#  4   Temperature   421570 non-null  float64
#  5   Fuel_Price    421570 non-null  float64
#  6   MarkDown1     150681 non-null  float64
#  7   MarkDown2     111248 non-null  float64
#  8   MarkDown3     137091 non-null  float64
#  9   MarkDown4     134967 non-null  float64
#  10  MarkDown5     151432 non-null  float64
#  11  CPI           421570 non-null  float64
#  12  Unemployment  421570 non-null  float64
#  13  IsHoliday     421570 non-null  bool
#  14  Dept          421570 non-null  int64
#  15  Weekly_Sales  421570 non-null  float64
# dtypes: bool(1), float64(10), int64(3), object(2)
# ...

# %%
df_merge.describe()
# Out:
#                Store           Size    Temperature     Fuel_Price  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546  136727.915739      60.090059       3.361027
# std        12.785297   60980.583328      18.447931       0.458515
# min         1.000000   34875.000000      -2.060000       2.472000
# 25%        11.000000   93638.000000      46.680000       2.933000
# 50%        22.000000  140167.000000      62.090000       3.452000
# 75%        33.000000  202505.000000      74.280000       3.738000
# max        45.000000  219622.000000     100.140000       4.468000
#
#            MarkDown1      MarkDown2      MarkDown3      MarkDown4  \
# count  150681.000000  111248.000000  137091.000000  134967.000000
# mean     7246.420196    3334.628621    1439.421384    3383.168256
# std      8291.221345    9475.357325    9623.078290    6292.384031
# min         0.270000    -265.760000     -29.100000       0.220000
# ...

# %%
df_merge['Date'] = pd.to_datetime(df_merge['Date'],format='%d/%m/%Y')

# %%
df_temp = df_merge.copy(deep=True)
df_temp['MarkDown'] = df_temp['MarkDown1'] + df_temp['MarkDown2'] +df_temp['MarkDown3'] +df_temp['MarkDown4'] + df_temp['MarkDown5']
df_temp.drop(['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'], inplace = True, axis = 1)

# %%
df_temp.head(2)
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price         CPI  \
# 0      1    A  151315 2010-02-05        42.31       2.572  211.096358
# 1      1    A  151315 2010-02-05        42.31       2.572  211.096358
#
#    Unemployment  IsHoliday  Dept  Weekly_Sales  MarkDown
# 0         8.106      False     1      24924.50       NaN
# 1         8.106      False     2      50605.27       NaN

# %%
df_temp.dtypes
# Out:
# Store                    int64
# Type                    object
# Size                     int64
# Date            datetime64[ns]
# Temperature            float64
# Fuel_Price             float64
# CPI                    float64
# Unemployment           float64
# IsHoliday                 bool
# Dept                     int64
# Weekly_Sales           float64
# MarkDown               float64
# dtype: object

# %%
df_temp['Type'].unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
df_temp.shape
# Out:
# (421570, 12)

# %%
df_temp.isna().sum()
# Out:
# Store                0
# Type                 0
# Size                 0
# Date                 0
# Temperature          0
# Fuel_Price           0
# CPI                  0
# Unemployment         0
# IsHoliday            0
# Dept                 0
# Weekly_Sales         0
# MarkDown        324514
# dtype: int64

# %% [markdown]
# # **Gain some graphical insight**

# %%
df_temp.head(2)
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price         CPI  \
# 0      1    A  151315 2010-02-05        42.31       2.572  211.096358
# 1      1    A  151315 2010-02-05        42.31       2.572  211.096358
#
#    Unemployment  IsHoliday  Dept  Weekly_Sales  MarkDown
# 0         8.106      False     1      24924.50       NaN
# 1         8.106      False     2      50605.27       NaN

# %%
numeric_df = df_temp.select_dtypes(include='number')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(numeric_df.corr(),annot= True)
# Out:
# <Axes: >

# %%
df_merge.columns
# Out:
# Index(['Store', 'Type', 'Size', 'Date', 'Temperature', 'Fuel_Price',
#        'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI',
#        'Unemployment', 'IsHoliday', 'Dept', 'Weekly_Sales'],
#       dtype='object')

# %%
df_merge[['Date', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 
    'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']].plot(x='Date', subplots=True, figsize=(20,15 ))
plt.show()

# %%
df_temp = df_merge.groupby('Date').sum()['Weekly_Sales'].reset_index()
fig, ax = plt.subplots(figsize=(20,12))
ax.plot('Date', 'Weekly_Sales', data=df_temp)

# %%
df_merge.Date.apply(lambda x: x.month)
# Out:
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
#           ..
# 421565    10
# 421566    10
# 421567    10
# 421568    10
# 421569    10
# Name: Date, Length: 421570, dtype: int64

# %%
df_merge.head(2)
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price  MarkDown1  \
# 0      1    A  151315 2010-02-05        42.31       2.572        NaN
# 1      1    A  151315 2010-02-05        42.31       2.572        NaN
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        NaN        NaN        NaN        NaN  211.096358         8.106
# 1        NaN        NaN        NaN        NaN  211.096358         8.106
#
#    IsHoliday  Dept  Weekly_Sales
# 0      False     1      24924.50
# 1      False     2      50605.27

# %%
df_merge.dtypes
# Out:
# Store                    int64
# Type                    object
# Size                     int64
# Date            datetime64[ns]
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# IsHoliday                 bool
# Dept                     int64
# Weekly_Sales           float64
# dtype: object

# %%
df_temp = df_merge.groupby(df_merge.Date.apply(lambda x: x.month))['Weekly_Sales'].sum().reset_index()
plt.figure(figsize=(10, 5))
sns.barplot(x=df_temp.Date,y=df_temp.Weekly_Sales)
plt.title("Month wise Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
df_temp = df_merge.groupby('Type')['Weekly_Sales'].sum().reset_index()

fig, ax = plt.subplots(figsize=(20,12))
ax.bar('Type', 'Weekly_Sales', data=df_temp)
plt.title("type Sales")
plt.xlabel("Type")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
df_merge
# Out:
#         Store Type    Size       Date  Temperature  Fuel_Price  MarkDown1  \
# 0           1    A  151315 2010-02-05        42.31       2.572        NaN
# 1           1    A  151315 2010-02-05        42.31       2.572        NaN
# 2           1    A  151315 2010-02-05        42.31       2.572        NaN
# 3           1    A  151315 2010-02-05        42.31       2.572        NaN
# 4           1    A  151315 2010-02-05        42.31       2.572        NaN
# ...       ...  ...     ...        ...          ...         ...        ...
# 421565     45    B  118221 2012-10-26        58.85       3.882    4018.91
# 421566     45    B  118221 2012-10-26        58.85       3.882    4018.91
# 421567     45    B  118221 2012-10-26        58.85       3.882    4018.91
# 421568     45    B  118221 2012-10-26        58.85       3.882    4018.91
# 421569     45    B  118221 2012-10-26        58.85       3.882    4018.91
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# ...

# %%
df_merge[['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']] = df_merge[['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']].fillna(0)

df_merge.head()
# Out:
#    Store Type    Size       Date  Temperature  Fuel_Price  MarkDown1  \
# 0      1    A  151315 2010-02-05        42.31       2.572        0.0
# 1      1    A  151315 2010-02-05        42.31       2.572        0.0
# 2      1    A  151315 2010-02-05        42.31       2.572        0.0
# 3      1    A  151315 2010-02-05        42.31       2.572        0.0
# 4      1    A  151315 2010-02-05        42.31       2.572        0.0
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        0.0        0.0        0.0        0.0  211.096358         8.106
# 1        0.0        0.0        0.0        0.0  211.096358         8.106
# 2        0.0        0.0        0.0        0.0  211.096358         8.106
# 3        0.0        0.0        0.0        0.0  211.096358         8.106
# 4        0.0        0.0        0.0        0.0  211.096358         8.106
#
#    IsHoliday  Dept  Weekly_Sales
# 0      False     1      24924.50
# 1      False     2      50605.27
# ...

# %%
df_merge.isna().sum()
# Out:
# Store           0
# Type            0
# Size            0
# Date            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday       0
# Dept            0
# Weekly_Sales    0
# dtype: int64

# %%
df_merge.to_csv('retail_final.csv', index=False)
